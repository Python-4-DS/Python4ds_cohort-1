# %% [markdown]
# # Testing of Miscellaneous code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('F:/isaka/python4DS/kiva_loans.csv')
data['repayment_interval'].value_counts().values
# Out:
# array([342717, 257158,  70728,    602], dtype=int64)
