# %% [markdown]
# # Introduction to Ipython

# %% [markdown]
# ## <font color=blue> Practice with ? and ?? help commands </font>

# %%
# Help on the len() function
len?

# %%
# Test function
def add(a, b):
    """ Return the sum of a and b """
    return a + b

# %%
# Help on add method
add?

# %%
# Access the source code of the method
add??

# %% [markdown]
# ## <font color=blue> Error Handling and Debugging </font>
# This involves using Exception mode and python debugger to trace errors

# %%
# A test function aimed at raising an exception
def calculate(x, y):
    """ Return the quotient of x and y """
    return eval(x / y)

# %%
# Turn Exception mode on to Plain and debugger then call the function
# %xmode Plain
# %pdb on
calculate(1, 0)
# Out:
# Exception reporting mode: Plain
# Automatic pdb calling has been turned ON
# Traceback (most recent call last):
#
#   File "<ipython-input-3-f08211720457>", line 4, in <module>
#     calculate(1, 0)
#
#   File "<ipython-input-1-401f9b733d7b>", line 4, in calculate
#     return eval(x / y)
#
# ZeroDivisionError: division by zero
# > <ipython-input-1-401f9b733d7b>(4)calculate()
#       1 # A test function aimed at raising an exception
#       2 def calculate(x, y):
#       3     """ Return the quotient of x and y """
# ----> 4     return eval(x / y)
#
# ipdb> quit

# %% [markdown]
# ## <font color=blue> Timing and Profiling </font>
# `%timeit` and `%%timeit` to show execution time

# %%
# %timeit sum(range(100))
# Out:
# 4.13 µs ± 452 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
